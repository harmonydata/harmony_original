# %% [markdown]
# # Evaluate the Harmony question matcher using the existing McElroy et al harmonisation tool as a gold standard
#
# This is a validation of Harmony against the questionnaire harmonisation tool developed by McElroy et al in 2020.
#
# You can read in detail about the validation report here:
#
# https://harmonydata.org/measuring-the-performance-of-nlp-algorithms/
#
# You can read an explanation of the technologies evaluated here:
#
# https://harmonydata.org/how-does-harmony-work/

# %%
MODEL_NAME = "Model 5: Transformer with dot product similarity\ndistiluse-base-multilingual-cased-v2"

import sys
sys.path.append("../front_end")
from utils.question_matcher_transformer_huggingface_negation_efficient import QuestionMatcherTransformerHuggingFaceNegationEfficient
qm = QuestionMatcherTransformerHuggingFaceNegationEfficient('sentence-transformers/distiluse-base-multilingual-cased-v2')
match_function = lambda question_dfs : qm.match_questions(question_dfs, is_disable_negation=True)
# Out:
# /media/thomas/642d0db5-2c98-4156-b591-1a3572c5868c/anaconda3/envs/harmony/lib/python3.10/site-packages/torch/cuda/__init__.py:83: UserWarning: CUDA initialization: CUDA unknown error - this may be due to an incorrectly set up environment, e.g. changing env variable CUDA_VISIBLE_DEVICES after program start. Setting the available devices to be zero. (Triggered internally at  ../c10/cuda/CUDAFunctions.cpp:109.)
#   return torch._C._cuda_getDeviceCount() > 0

# %%
from load_validation_data import validation_data
from validation import validate

# %%
validate(validation_data, match_function, MODEL_NAME)
# Out:
# Validating on dataset McElroy et al Childhood
# 	Processing 47 instruments of average length 23 questions each
# /media/thomas/642d0db5-2c98-4156-b591-1a3572c5868c/anaconda3/envs/harmony/lib/python3.10/site-packages/sentence_transformers/util.py:58: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at  ../torch/csrc/utils/tensor_new.cpp:204.)
#   a = torch.tensor(a)
# 	Calculated 562315 match scores
# 	Generated 40708 gold-standard values to compare them to
# 	Calculating ROC curve
#
# FALSE NEGATIVES OR WEAKEST MATCHES McElroy et al Childhood
#                                                      Instrument 1  \
# 0                                          Tries to Stop Quarrels
# 1   Child likes to sit and watch TV rather than play active games
# 2                                          Tries to Stop Quarrels
# 3                                           Is squirmy or fidgety
# 4   She is off and running as soon as she wakes up in the morning
# 5                                          Tries to Stop Quarrels
# 6                                              Does things on Own
# 7                                               Stares into Space
# 8               I felt so tired I just sat around and did nothing
# 9                                          Is Squirmy and Fidgety
# 10                                              Doesnt Share Toys
#
#                                                                 Instrument 2  \
# 0                        Is helpful if someone is hurt, upset or feeling ill
# 1                                                        "A very hard worker
# 2             Shares readily with other children (treats, toys, pencils etc)
# 3             Child cannot settle to do anything for more than a few moments
# 4                                                        I was very restless
# 5        Often volunteers to help others (parents, teachers, other children)
# 6   does not seem able to make friends" or "Very popular with other children
# 7                          I felt so tired I just sat around and did nothing
# 8                                                        "Normally energetic
# 9             Child cannot settle to do anything for more than a few moments
# 10                       Is helpful if someone is hurt, upset or feeling ill
#
#     Score from model  Ground truth
# 0               0.00             1
# 1               0.00             1
# 2               0.00             1
# 3               0.01             1
# 4               0.01             1
# 5               0.01             1
# 6               0.02             1
# 7               0.02             1
# 8               0.02             1
# 9               0.02             1
# 10              0.02             1
# FALSE POSITIVES OR WEAKEST REJECTIONS McElroy et al Childhood
#                                                                Instrument 1  \
# 0                                      Overcompetitive with other children"
# 1                                               Gets on With Other Children
# 2                                               Gets on With Other Children
# 3                                              Other Children Dislike Child
# 4                                                Fights With Other Children
# 5                                              Child bullies other children
# 6   usually gloomy and sad" or "Normal attitude to criticism and punishment
# 7                                               Gets on With Other Children
# 8                                              Other Children Dislike Child
# 9                                               Gets on With Other Children
# 10                                                   Bullies Other Children
#
#                                                                Instrument 2  \
# 0                            diffident about competing with other children"
# 1                                                Fights with other children
# 2                            Interferes with the activity of other children
# 3                                              Child bullies other children
# 4                                      Overcompetitive with other children"
# 5                                              Is bullied by other children
# 6   frequently disobedient" or "Normal attitude to criticism and punishment
# 7                                      Overcompetitive with other children"
# 8                                                    Bullies other children
# 9                                          Child fights with other children
# 10                                             Is bullied by other children
#
#     Score from model  Ground truth
# 0               0.90             0
# 1               0.89             0
# 2               0.81             0
# 3               0.80             0
# 4               0.80             0
# 5               0.80             0
# 6               0.80             0
# 7               0.80             0
# 8               0.79             0
# 9               0.79             0
# 10              0.76             0
# Validating on dataset McElroy et al Adulthood
# 	Processing 28 instruments of average length 16 questions each
# 	Calculated 95600 match scores
# 	Generated 9468 gold-standard values to compare them to
# 	Calculating ROC curve
#
# FALSE NEGATIVES OR WEAKEST MATCHES McElroy et al Adulthood
#                                                                                     Instrument 1  \
# 0                                                                                  I cried a lot
# 1                                                                         I did everything wrong
# 2                                                                         I did everything wrong
# 3                                                                         I did everything wrong
# 4                                                               I thought nobody really loved me
# 5                                                                                I laughed a lot
# 6   Do you often feel on edge, or keyed up, or mentally tense or strained (rate nervous tension)
# 7                                                                    I felt miserable or unhappy
# 8                                             I thought I would never be as good as other people
# 9                                                               I thought nobody really loved me
# 10                                                                                I hated myself
#
#                                                                                                                                                                                                       Instrument 2  \
# 0   Been able to enjoy your normal daytoday activities (*note  this is the closest approximation of 'low mood' identified in this measure This items may be better conceptualised as capturing 'loss of interest')
# 1                                                                                                                                What is your opinion of yourself compared to other people (rate selfdepreciation)
# 2                                                                                                                                              How confident do you feel in yourself (rate lack of selfconfidence)
# 3                                                                                                                                                 Are you selfconscious in public (rate simple ideas of reference)
# 4                                                                                                                                                         Been satisfied with the way you've carried out your task
# 5   Been able to enjoy your normal daytoday activities (*note  this is the closest approximation of 'low mood' identified in this measure This items may be better conceptualised as capturing 'loss of interest')
# 6                                                                                                                                                                           Found everything getting on top of you
# 7   Been able to enjoy your normal daytoday activities (*note  this is the closest approximation of 'low mood' identified in this measure This items may be better conceptualised as capturing 'loss of interest')
# 8                                                                                                                                                         Been satisfied with the way you've carried out your task
# 9                                                                                                                                                 Are you selfconscious in public (rate simple ideas of reference)
# 10                                                                                                                                                               Felt that you are playing a useful part in things
#
#     Score from model  Ground truth
# 0               0.01             1
# 1               0.03             1
# 2               0.03             1
# 3               0.04             1
# 4               0.04             1
# 5               0.05             1
# 6               0.05             1
# 7               0.05             1
# 8               0.06             1
# 9               0.06             1
# 10              0.06             1
# FALSE POSITIVES OR WEAKEST REJECTIONS McElroy et al Adulthood
#                                                   Instrument 1  \
# 0             Do you suddenly become scared for no good reason
# 1                                  Do you often feel depressed
# 2                          Have you been a very nervous person
# 3   Are you frightened of going out alone or of meeting people
# 4                          Felt that life is entirely hopeless
# 5       Do you often suddenly become scared for no good reason
# 6                                  Do you often feel depressed
# 7                     Do you often feel tired most of the time
# 8                                        Did you feel worn out
# 9                            Have you felt downhearted and low
# 10                                          Did you feel tired
#
#                                                       Instrument 2  \
# 0                Been getting scared or panicky for no good reason
# 1                         Do you often feel tired most of the time
# 2                            Have you ever had a nervous breakdown
# 3   Are you scared to be alone when there are not friends near you
# 4                                Felt that life isn't worth living
# 5                Been getting scared or panicky for no good reason
# 6                               Do you feel tired most of the time
# 7                         Do you often feel miserable or depressed
# 8                                            Felt that you are ill
# 9                                            Did you feel worn out
# 10                                           Felt that you are ill
#
#     Score from model  Ground truth
# 0               0.77             0
# 1               0.74             0
# 2               0.73             0
# 3               0.72             0
# 4               0.72             0
# 5               0.71             0
# 6               0.71             0
# 7               0.71             0
# 8               0.70             0
# 9               0.69             0
# 10              0.69             0
# Validating on dataset GAD-7 (EN/PT)
# Found Portuguese dataset GAD-7 (EN/PT)
# Found Portuguese dataset GAD-7 (EN/PT)
# 	Processing 2 instruments of average length 7 questions each
# 	Calculated 49 match scores
# 	Generated 49 gold-standard values to compare them to
# 	Calculating ROC curve
#
# FALSE NEGATIVES OR WEAKEST MATCHES GAD-7 (EN/PT)
#                                          Instrument 1  \
# 0      Being so restless that it is hard to sit still
# 1                Feeling nervous, anxious, or on edge
# 2            Worrying too much about different things
# 3                Becoming easily annoyed or irritable
# 4          Not being able to stop or control worrying
# 5  Feeling afraid, as if something awful might happen
# 6                                    Trouble relaxing
#
#                                                     Instrument 2  \
# 0  Ficar tão agitado/a que se torna difícil permanecer sentado/a
# 1                Sentir-se nervoso/a, ansioso/a ou muito tenso/a
# 2                         Preocupar-se muito com diversas coisas
# 3                    Ficar facilmente aborrecido/a ou irritado/a
# 4       Não ser capaz de impedir ou de controlar as preocupações
# 5              Sentir medo como se algo horrível fosse acontecer
# 6                                       Dificuldade para relaxar
#
#    Score from model  Ground truth
# 0              0.59             1
# 1              0.64             1
# 2              0.65             1
# 3              0.73             1
# 4              0.75             1
# 5              0.76             1
# 6              0.82             1
# FALSE POSITIVES OR WEAKEST REJECTIONS GAD-7 (EN/PT)
#                                           Instrument 1  \
# 0       Being so restless that it is hard to sit still
# 1                 Becoming easily annoyed or irritable
# 2                 Feeling nervous, anxious, or on edge
# 3                 Becoming easily annoyed or irritable
# 4                 Becoming easily annoyed or irritable
# 5   Feeling afraid, as if something awful might happen
# 6                                     Trouble relaxing
# 7                 Becoming easily annoyed or irritable
# 8                                     Trouble relaxing
# 9                 Feeling nervous, anxious, or on edge
# 10            Worrying too much about different things
#
#                                                      Instrument 2  \
# 0                                        Dificuldade para relaxar
# 1                                        Dificuldade para relaxar
# 2                     Ficar facilmente aborrecido/a ou irritado/a
# 3                 Sentir-se nervoso/a, ansioso/a ou muito tenso/a
# 4   Ficar tão agitado/a que se torna difícil permanecer sentado/a
# 5                 Sentir-se nervoso/a, ansioso/a ou muito tenso/a
# 6                     Ficar facilmente aborrecido/a ou irritado/a
# 7        Não ser capaz de impedir ou de controlar as preocupações
# 8   Ficar tão agitado/a que se torna difícil permanecer sentado/a
# 9                                        Dificuldade para relaxar
# 10              Sentir medo como se algo horrível fosse acontecer
#
#     Score from model  Ground truth
# 0               0.53             0
# 1               0.48             0
# 2               0.44             0
# 3               0.42             0
# 4               0.40             0
# 5               0.39             0
# 6               0.38             0
# 7               0.36             0
# 8               0.35             0
# 9               0.34             0
# 10              0.34             0
# Validating on dataset BHRCS SDQ/CBCL (PT)
# Found Portuguese dataset BHRCS SDQ/CBCL (PT)
# Found Portuguese dataset BHRCS SDQ/CBCL (PT)
# 	Processing 2 instruments of average length 73 questions each
# 	Calculated 3025 match scores
# 	Generated 3025 gold-standard values to compare them to
# 	Calculating ROC curve
#
# FALSE NEGATIVES OR WEAKEST MATCHES BHRCS SDQ/CBCL (PT)
#                                                    Instrument 1  \
# 0                                     É alvo de muitas gozações
# 1                                        É barulhento(a) demais
# 2                                                   Grita muito
# 3                                  Fica emburrado(a) facilmente
# 4                                                   Fala demais
# 5                                         Não vai bem na escola
# 6   Não consegue tirar certos pensamentos da cabeça (obsessões)
# 7                              É muito acanhado(a) ou tímido(a)
# 8                              É impulsivo(a) ou age sem pensar
# 9                                      É nervoso(a) ou tenso(a)
# 10                      É desatento(a) ou distrai-se facilmente
#
#                                                                                                    Instrument 2  \
# 0                                                                   Outras crianças pegam no pé ou a atormentam
# 1                                                                            Pensa nas coisas antes de fazê-las
# 2                                                        Frequentemente tem acessos de raiva ou crises de birra
# 3                                                        Frequentemente tem acessos de raiva ou crises de birra
# 4                                                                            Pensa nas coisas antes de fazê-las
# 5                                                          Completa as tarefas que começa, tem boa concentração
# 6                                              Tem muitas preocupações, muitas vezes parece preocupado com tudo
# 7   Fica inseguro quando tem que fazer alguma coisa pela primeira vez, facilmente perde a confiança em si mesmo
# 8                                                                            Pensa nas coisas antes de fazê-las
# 9                                              Tem muitas preocupações, muitas vezes parece preocupado com tudo
# 10                                                                              Facilmente perde a concentração
#
#     Score from model  Ground truth
# 0               0.03             1
# 1               0.03             1
# 2               0.05             1
# 3               0.06             1
# 4               0.06             1
# 5               0.08             1
# 6               0.08             1
# 7               0.10             1
# 8               0.12             1
# 9               0.12             1
# 10              0.14             1
# FALSE POSITIVES OR WEAKEST REJECTIONS BHRCS SDQ/CBCL (PT)
#                                                      Instrument 1  \
# 0   Desrespeita as regras em casa, na escola ou em outros lugares
# 1                           As outras crianças não gostam dele(a)
# 2                           Prefere estar com crianças mais novos
# 3                               Não se dá bem com outras crianças
# 4                     Tem medo de pensar ou fazer alguma coisa má
# 5                     É cruel, intimida ou faz maldade com outros
# 6                           Prefere estar com crianças mais novos
# 7                                              Reclama de solidão
# 8                               Não se dá bem com outras crianças
# 9                                       Mente ou engana os outros
# 10                                      Mente ou engana os outros
#
#                                                                Instrument 2  \
# 0                      Rouba coisas de casa, da escola ou de outros lugares
# 1                               Outras crianças pegam no pé ou a atormentam
# 2                         Se dá melhor com adultos do que com outros jovens
# 3                               Outras crianças pegam no pé ou a atormentam
# 4                                   Tem muitos medos, assusta-se facilmente
# 5   Tenta ser atencioso se alguém parece magoado, aflito ou se sentindo mal
# 6                                          É gentil com crianças mais novas
# 7                                      É solitário, prefere brincar sozinho
# 8                         Se dá melhor com adultos do que com outros jovens
# 9                    Frequentemente briga com outros jovens ou os amedronta
# 10                     Tem consideração pelos sentimentos de outras pessoas
#
#     Score from model  Ground truth
# 0               0.43             0
# 1               0.39             0
# 2               0.39             0
# 3               0.39             0
# 4               0.38             0
# 5               0.36             0
# 6               0.35             0
# 7               0.35             0
# 8               0.34             0
# 9               0.34             0
# 10              0.34             0
